# %% [markdown]
# ---
# # ONE SHOT
# ---
# ### Ajout de la table monitor
# #### Cette table devrait être créée au moment d'initdb mais elle a été conçue une fois que la base est déjà constituée et on ne veut pas drop les autres tables, donc on crée monitor individuellement.
#
# Remarque: les tables forecasts, jobs sont créées de la même façon mais à prtir des notebooks 03 et 04

# %%
from pipeline.core.src.sql import get_engine, create_table_monitor

engine = get_engine()
create_table_monitor(engine)
# Out:
# [INFO] pipeline_sql: Engine created — neondb_owner@ep-quiet-sun-al5bcj46-pooler.c-3.eu-central-1.aws.neon.tech/DB_NAME
# [INFO] pipeline_sql: Table ready: theguardian.monitor
